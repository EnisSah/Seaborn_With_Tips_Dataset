# %% [markdown]
# ### we don't need to load any data, because this data set is already in Seaborn

# %% [markdown]
# ## 2. Line Graphs

# %%
t = sns.lineplot(x='day', y='tip', data=tips, ci=None)

# %%
t = sns.lineplot(x='total_bill', y='tip', data=tips, ci=None)

# %%
t = sns.lineplot(x='size', y='tip', data=tips, ci=None)

# %%
t = sns.lineplot(x='sex', y='tip', data=tips, ci=None)

# %%
t = sns.lineplot(x='smoker', y='tip', data=tips, ci=None)

# %%
#palette = sns.color_palette("mako_r", 6)
palette=sns.color_palette("hls", 6)
t = sns.lineplot(x='total_bill', y='tip', hue='size',data=tips, ci=None, palette=palette)
#sns.lineplot(sns.color_palette("hls", 8))

# %%
#palette = sns.color_palette("mako_r", 6)
palette=sns.color_palette("Paired", 6)
t = sns.lineplot(x='total_bill', y='tip', hue='size',style='size' ,data=tips, ci=None, palette=palette)
#sns.lineplot(sns.color_palette("hls", 8))

# %%
#palette = sns.color_palette("mako_r", 6)
flatui = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]
palette = sns.color_palette(flatui)
sns.set(rc={'figure.figsize':(12,8)})
t = sns.lineplot(x='total_bill', y='tip', hue='size', style='size',data=tips, ci=None, palette=palette)
#sns.lineplot(sns.color_palette("hls", 8))

# %%
t = sns.lineplot(x='total_bill', y='tip', hue = 'size', style = 'size', data = tips, ci=None,  markers=True)

# %%
# Example 6 - By day with style & Increase the size & Remove error bars & adding markers 


t = sns.lineplot(x='total_bill', y='tip', hue = 'day', style = 'size', data = tips, ci=None,  markers=True)

# %%
# Example 7 - by sex with style and increase the size and remove bars  and adding month
t = sns.lineplot(x='sex', y='tip', hue = 'day', style = 'size', data = tips, ci=None,  markers=True)

# %%
# Example 8 - by smoker with style and increase the size and remove bars  and adding month
t = sns.lineplot(x='smoker', y='tip', hue = 'day', style = 'size', data = tips, ci=None,  markers=True)

# %%
# Example 9 - by time with style and increase the size and remove bars  and adding month
t = sns.lineplot(x='time', y='tip', hue = 'day', style = 'size', data = tips, ci=None,  markers=True)

# %% [markdown]
# ## 3. Bar Plots

# %%
tips ['tip']
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
tips['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
t = sns.barplot(x='day', y='total_bill',data=tips)
#t[['day','total_bill']].groupby('day',as_index=False).agg({'total_bill': 'mean'})

# %%
t = sns.barplot(x='day', y='tip',data=tips, ci=False)
#t[['tip','total_bill']].groupby('tip',as_index=False).agg({'total_bill': 'mean'})

# %%
# Total tip by day, remove CI, by sex
# Blue is color for boy babies and pink is for girl babies :)

colors = ['#0000ff','#ff00ff']
t = sns.barplot(x='day', y='tip',hue= 'sex',data=tips, ci=False, palette=colors)

# %%
# Total bill by day, remove CI, by sex
# Blue is color for boy babies and pink is for girl babies :)

colors = ['#0000ff','#ff00ff']
t = sns.barplot(x='day', y='total_bill',hue= 'sex',data=tips, ci=False,palette=colors)

# %%
# Total tip by day, remove CI, by smoker
# Black color should represent that smoking is bad for your health
# while the green color should say the opposite

colors = ['#001a0f','#00ff99']
t = sns.barplot(x='day', y='tip',hue= 'smoker',data=tips, ci=False, palette=colors)

# %%
# Total bill by day, remove CI, by smoker
# Black color should say that smoking is bad for your health
# while the green color should say the opposite

colors = ['#001a0f','#00ff99']
t = sns.barplot(x='day', y='total_bill',hue= 'smoker',data=tips, ci=False, palette=colors)

# %%
# Total tips by day
#ax = sns.barplot(x="tip", y="day", ci=False, hue = 'Promo', orient = 'h', data=raw_data)
t = sns.barplot(x="tip", y="day", ci=False, orient = 'h', data=tips)

# %%
# Totall bill by day
ax = sns.barplot(x="total_bill", y="day", ci=False, orient = 'h', data=tips)

# %%
# Totall tip by day, by sex
colors = ['#0000ff','#ff00ff']
ax = sns.barplot(x="tip", y="day", hue='sex', ci=False, orient = 'h', data=tips, palette=colors)

# %%
# Totall bill by day, by sex
colors = ['#0000ff','#ff00ff']
ax = sns.barplot(x="total_bill", y="day", hue='sex', ci=False, orient = 'h', data=tips, palette=colors)

# %%
# Totall bill by day, by size
#colors = ['#0000ff','#ff00ff']
ax = sns.barplot(x="total_bill", y="day", hue='size', ci=False, orient = 'h', data=tips, color='#99e699')

# %%
# Totall bill by day, by time
colors = ['#ffff80','#ffd480']
ax = sns.barplot(x="total_bill", y="day", hue='time', ci=False, orient = 'h', data=tips, palette=colors)

# %% [markdown]
# ## 4. Histograms

# %%
# Example 1.  - Investigating the distribution of Totall Bill
x = tips ['total_bill'].values

sns.distplot(x, color ='green')

# %%
# Example 2.  - Investigating the distribution of Totall Bill
x = tips ['total_bill'].values

sns.distplot(x, color ='#9933ff')


# calculating the mean
mean = tips['total_bill'].mean()

#ploting the mean
plt.axvline(mean, 0,1, color = '#26004d')

# %%
# Example 3.  - Investigating the distribution of tips
x = tips ['tip'].values

sns.distplot(x, color ='#ff9933')

# %%
# Example 4.  - Investigating the distribution of tips
x = tips ['tip'].values
sns.distplot(x, color ='#00cccc')

# calculating the mean
mean = tips['tip'].mean()

#ploting the mean
plt.axvline(mean, 0,1, color = '#003333')

# %% [markdown]
# ## 5. Box Plots

# %%
# Example 1 - Investigating the distribution of tips
x = tips['tip'].values

ax = sns.boxplot(x, color ='#00ffff')

print('The meadian is: ', tips['tip'].median())
# Out:
# The meadian is:  2.9

# %%
# Example 2 - Investigating the distribution of totall bill
x = tips['total_bill'].values

ax = sns.boxplot(x,color='#66ff1a')

print('The meadian is: ', tips['total_bill'].median())
# Out:
# The meadian is:  17.795

# %%
# Example 3 - Investigating the distribution of totall bill by day

palette = sns.color_palette("ch:2.5,-.2,dark=.4")
ax = sns.boxplot(x="day", y="total_bill", data=tips, palette = palette)

# %%
# Example 4 - Investigating the distribution of tips by day

palette = sns.color_palette("RdBu")
ax = sns.boxplot(x="day", y="total_bill", data=tips, palette = palette)

# %%
# Example 5 - Investigating the distribution of tips by day
palette = (sns.color_palette("ch:2.5,.2,dark=.3"))
ax = sns.boxplot(x="total_bill", y="day", data=tips, palette=palette)

# %%
# Example 6 - Investigating the distribution of total bill by day, by sex
ax = sns.boxplot(x="day", y="total_bill", data=tips, color="#B971E7", hue = 'sex')
ax.legend(loc='upper center')

# %%
# Example 7 - Investigating the distribution of total bill by day, by smoker
ax = sns.boxplot(x="day", y="total_bill", data=tips, color="#00e600", hue = 'smoker')
ax.legend(loc='upper center')

# %%
# Example 8 - Investigating the distribution of tip by day, by smoker
palette=['#805500','#00ff00']
ax = sns.boxplot(x="day", y="tip", data=tips, color="#66d9ff", hue = 'smoker', palette=palette)
ax.legend(loc='upper center')

# %%
# Example 9 - Investigating the distribution of tip by day, by sex
palette=['#0000e6','#ff00ff']
ax = sns.boxplot(x="day", y="tip", data=tips, color="#66d9ff", hue = 'sex', palette=palette)
ax.legend(loc='upper center')

# %%
# Example 10 - Investigating the distribution of total bill by day, by data points
ax = sns.boxplot(x="day", y="total_bill", data=tips, color = '#bb99ff')
ax = sns.swarmplot(x="day", y="total_bill", data=tips, color="#220066")

# %%
# Example 11 - Investigating the distribution of tip by day, by data points
ax = sns.boxplot(x="day", y="tip", data=tips, color = '#99ebff')
ax = sns.swarmplot(x="day", y="tip", data=tips, color="#006680")

# %% [markdown]
# ## 6. ScatterPlots

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
# Example 1 - Relationship between total bill  and tips
ax = sns.scatterplot(x="tip", y="total_bill", data=tips)

# %%
# Example 2 - Relationship between total bill  and tips, hue and stype
ax = sns.scatterplot(x="tip", y="total_bill",hue="day", style="day", data=tips)

# %%
# Example 3 - Relationship between total bill  and tips, hue and stype, and size
ax = sns.scatterplot(x="tip", y="total_bill",hue="day", style="day", size = 'total_bill',
                     data=tips, sizes=(10,330))

# %%
# Example 3 - Relationship between total bill  and tips, hue and stype, and size

ax = sns.scatterplot(x="tip", y="total_bill",hue="day", style="day", size = 'tip',
                     data=tips, sizes=(10,300))

# %%
# Example 4 - Relationship between total bill  and tips, hue and stype, and smoker
palette=["#00ff00",'#805500']
ax = sns.scatterplot(x="tip", y="total_bill",hue="smoker", style="smoker", size = 'tip',
                     data=tips,palette=palette ,sizes=(10,300))

# %%
# Example 5 - Relationship between total bill  and tips, hue and stype, and sex
palette=['#0000e6','#ff00ff']
ax = sns.scatterplot(x="total_bill", y="tip",hue="sex", style="sex", size = 'tip',
                     data=tips, palette=palette ,sizes=(20,300))

# %% [markdown]
# ## 7. ImPlots

# %%
# Example 1 - Relationship between total bill  and tip
ax = sns.lmplot(x="total_bill", y="tip", data=tips, height=8)

# %%
# Example 2 - Relationship between total bill  and tip, changing hue and style
ax = sns.lmplot(x="total_bill", y="tip", hue="day", ci= False,
                data=tips, height=8, markers=["o", "x", "+", "*"] )

# %%
# Example 3 - Relationship between total bill and tip - by column, by day

ax = sns.lmplot(x="total_bill", y="tip", data=tips, col = 'day', ci= False, height=5, 
                line_kws={'color': '#006666'}, 
                scatter_kws={'color':'#00e6e6'}, col_wrap=2)

# %%
# Example 4 - Relationship between total bill and tip - by column, by size

ax = sns.lmplot(x="total_bill", y="tip", data=tips, col = 'size', ci= False, height=5, 
                line_kws={'color': '#004d00'}, 
                scatter_kws={'color':'#00ff00'}, col_wrap=2, x_jitter=.10)

# %%
# Example5- Relationship between total bill and tip - by column, by sex

ax = sns.lmplot(x="total_bill", y="tip", data=tips, col = 'sex', ci= False, height=5, 
                line_kws={'color': '#001a66'}, 
                scatter_kws={'color':'#6666ff'}, col_wrap=2, x_jitter=.10)

# %%
# Example 6- Relationship between total bill and tip - by column, by smoker

ax = sns.lmplot(x="total_bill", y="tip", data=tips, col = 'smoker', ci= False, height=5, 
                line_kws={'color': '#660000'}, 
                scatter_kws={'color':'#ff8080'}, col_wrap=2, x_jitter=.10)

# %% [markdown]
# ## 8. SubPlots

# %%
# Set up the matplotlib figure
fig, axes = plt.subplots(2, 2, figsize=(12, 7))

a = tips['total_bill'].values
b = tips['tip'].values
c = tips['size'].values


# plot 1

sns.distplot(a, color = 'blue', ax=axes[0,0])
axes[0,0].set_title = 'Total Bill'

# plot 2
sns.distplot(b, color = 'blue', ax=axes[0,1])

# plot 3
sns.distplot(c, color = 'blue', ax=axes[1,0])

# plot 4
sns.boxplot(x="total_bill", y="day", data=tips, color = '#bfff00', ax=axes[1,1])
sns.swarmplot(x="total_bill", y="day", data=tips, color="#608000", ax=axes[1,1])

# %% [markdown]
# ## 9. Pairplots

# %%
# Example 1 - running on all dataframe - green color

#g = sns.pairplot(tips,plot_kws={'color':'green'})
g = sns.pairplot(tips, plot_kws={'color':'#00997a'})

# %%
# Example 2 - running on specific columns - green color
g = sns.pairplot(tips[['total_bill','tip']], plot_kws={'color':'#3399ff'})

# %%
# Example 3 - running on specific columns - adding hue
g = sns.pairplot(tips[['total_bill','tip','day', 'size']], hue = 'size')

# %%
# Example 4 - running on specific columns - adding hue
palette=['#0000e6','#ff00ff']
g = sns.pairplot(tips[['total_bill','tip','day', 'sex']],palette=palette, hue = 'sex')

# %%
# Example 5 - running on specific columns - adding hue
palette=['#805500','#00ff00']
g = sns.pairplot(tips[['total_bill','tip','day', 'smoker']],palette=palette, hue = 'smoker')

# %%
# Example 6 - running on specific columns - adding hue adding kind=reg
palette=['#00ff99','#0040ff','#ffb3b3',"#c61aff"]

g = sns.pairplot(tips[['total_bill','tip','day', 'smoker']],palette=palette, 
                 hue = 'day', kind='reg', size=6)
# Out:
# C:\Users\Ferdi\anaconda3\lib\site-packages\seaborn\axisgrid.py:2079: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## 10. JoinPlots

# %%
# Example 1 - totall bill vs tip Relationship with 
# ovde ne radi palette



g = sns.jointplot('total_bill','tip', data = tips,
                  color='#e65c00', kind='reg', size=10)
# Out:
# C:\Users\Ferdi\anaconda3\lib\site-packages\seaborn\axisgrid.py:2272: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## 11. Heat Map

# %%
# Example 1 - Heatmap for PC

pc = tips[['total_bill','tip', 'size']].corr(method ='pearson')

cols = ['total_bill','tip', 'size']

ax = sns.heatmap(pc, annot=True,
                 yticklabels=cols,
                 xticklabels=cols,
                 annot_kws={'size': 50})

# %%
# Example 2 - Heatmap for PC with defferent colors

pc = tips[['total_bill','tip', 'size']].corr(method ='pearson')

cols = ['total_bill','tip', 'size']

ax = sns.heatmap(pc,  cmap="YlGnBu", annot=True, annot_kws={'size': 30})

# %%
# Example 2 - Heatmap for PC - changing cmap

ax = sns.heatmap(pc, annot=True,
                 yticklabels=cols,
                 xticklabels=cols,
                 annot_kws={'size': 50},
                 cmap="Greens")

# %% [markdown]
# ## 12. Violin plot

# %%
sns.set(style="whitegrid", palette="pastel", color_codes=True)
sns.set(rc={'figure.figsize':(12,8)})
# Load the example tips dataset
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Draw a nested violinplot and split the violins for easier comparison
# Example 1

sns.violinplot(x="day", y="total_bill", hue="smoker",
               split=True, inner="quartile",
               palette=['#4d3319',"#00ff00"],
               data=tips)
sns.despine(left=True)

# %%
# Draw a nested violinplot and split the violins for easier comparison
# Example 2

sns.violinplot(x="day", y="total_bill", hue="sex",
               split=True, inner="quartile",
               palette=['#0000ff','#ff00ff'],
               data=tips)
sns.despine(left=True)
